# %%
# %matplotlib inline 

import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
plt.figure(); ts.plot(); plt.legend(loc='best')

# %%
# reading from txt file, with columns `hot	comment	vote	collect`

data = pd.read_table('data/hot.txt', delim_whitespace=True)
data
# Out:
#          hot  comment  vote  collect
# 0        110       21    89        0
# 1         82       15    67        0
# 2         53        1    52        0
# 3         67       10    57        0
# 4        154       24   130        0
# 5         73       20    53        0
# 6         66       11    55        0
# 7         33        0    33        0
# 8         71       18    53        0
# 9        432       29   402        1
# 10       156       45   111        0
# 11        61        0    61        0
# 12         9        0     9        0
# 13       488      216   270        2
# 14        56       17    39        0
# 15       143       54    89        0
# 16        54        7    47        0
# 17        49       10    39        0
# 18      1761      394  1363        4
# 19        97       15    82        0
# 20       558      120   438        0
# 21       481      115   366        0
# 22        41       15    25        1
# 23       145       10   135        0
# ...

# %%
hot = data['hot']
hot.cumsum()
print hot.describe()
plt.figure();hot.plot()
# Out:
# count    236269.000000
# mean         17.622485
# std         167.851496
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       23779.000000
# Name: hot, dtype: float64

# %%
#df = pd.DataFrame(data, index=data.index,  columns=['hot', 'comment', 'vote', 'collect'])
for c in ('hot', 'comment', 'vote', 'collect'):
    df = pd.DataFrame(data, index=data.index,  columns=[c,])
    plt.figure(); df.plot()
